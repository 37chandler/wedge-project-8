# %% [markdown]
# # Task 1 (Part 1): Process Large Zip Files

# %% [markdown]
# #### Import the Required Libraries

# %%
from zipfile import ZipFile
import pandas as pd
import os
import io
import csv
from datetime import datetime
import numpy as np
from google.cloud import bigquery

# %% [markdown]
# #### Setup the Data Directories

# %%
data_directory = "Data/LargeZips/"
zip_files = os.listdir("Data/LargeZips")

# %% [markdown]
# #### Setup the Schema

# %%
schema = [
    bigquery.SchemaField("datetime", "TIMESTAMP", mode="NULLABLE"),
    bigquery.SchemaField("register_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("emp_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("trans_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("upc", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("description", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_type", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_subtype", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_status", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("department", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("quantity", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("Scale", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("cost", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("unitPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("total", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("regPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("altPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("tax", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("taxexempt", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("foodstamp", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("wicable", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("memDiscount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discountable", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discounttype", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("voided", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("percentDiscount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("ItemQtty", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("volDiscType", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("volume", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("VolSpecial", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("mixMatch", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("matched", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("memType", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("staff", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("numflag", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("itemstatus", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("tenderstatus", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("charflag", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("varflag", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("batchHeaderID", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("local", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("organic", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("display", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("receipt", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("card_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("store", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("branch", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("match_id", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("trans_id", "FLOAT", mode="NULLABLE")
]

# %% [markdown]
# #### Asssign the Column Header Names

# %%
header_names = ['datetime', 'register_no', 'emp_no', 'trans_no', 'upc', 'description',
       'trans_type', 'trans_subtype', 'trans_status', 'department', 'quantity',
       'Scale', 'cost', 'unitPrice', 'total', 'regPrice', 'altPrice', 'tax',
       'taxexempt', 'foodstamp', 'wicable', 'discount', 'memDiscount',
       'discountable', 'discounttype', 'voided', 'percentDiscount', 'ItemQtty',
       'volDiscType', 'volume', 'VolSpecial', 'mixMatch', 'matched', 'memType',
       'staff', 'numflag', 'itemstatus', 'tenderstatus', 'charflag', 'varflag',
       'batchHeaderID', 'local', 'organic', 'display', 'receipt', 'card_no',
       'store', 'branch', 'match_id', 'trans_id']

# %% [markdown]
# #### Functions

# %%
# Function to cast a DataFrame to a specified schema
def cast_dataframe_to_schema(df, schema):
    print(f"Casting DataFrame to BigQuery schema")
    try:
        for field in schema:
            column_name = field.name
            field_type = field.field_type
 
            if column_name in df.columns:
                if field_type == "STRING":
                    df[column_name] = df[column_name].astype(str)
                elif field_type == "FLOAT":
                    df[column_name] = pd.to_numeric(df[column_name], errors='coerce')  # Coerce invalid values to NaN
                elif field_type == "BOOLEAN":
                    df[column_name] = df[column_name].apply(lambda x: bool(x) if pd.notnull(x) else None)  # Handle nulls
                elif field_type == "TIMESTAMP":
                    df[column_name] = pd.to_datetime(df[column_name], errors='coerce', utc=True)  # Convert to datetime and coerce errors
 
        df = df[[field.name for field in schema if field.name in df.columns]]
        return df
    except Exception as e:
        print(f"Error casting DataFrame to schema: {e}")
        raise

# %% [markdown]
# #### Processing The Zip Files
#
# This section opens all the large zip files, one at a time, and checks for delimiters and headers. If a header row is missing, the list of header names is added. Next, it converts the datetime to a Pandas datetime object. Additionally, it handles missing or null values and matches the schema to the desired schema for Goggle Big Query. Finally, the zip file is stored as a csv file in a file for processed files ready to upload to Big Query.

# %%
# Directory to save processed files
processed_files_directory = "data/processed_files/"

# Process ZIP files
zip_files = os.listdir(data_directory)

# Iterate over each zip file
for current_zf in zip_files:
    zip_file_path = os.path.join(data_directory, current_zf)
    with ZipFile(zip_file_path, 'r') as zf:
        zipped_files = zf.namelist()

        # Iterate over each file in the current zip file
        for file_name in zipped_files:
            with zf.open(file_name) as working_file:
                try:
                    # Open and wrap it to read as text and take a sample to find headers and delimiters
                    input_file = io.TextIOWrapper(working_file, encoding="utf-8")
                    sample = input_file.read(1024 * 4)  # Sample for sniffing

                    # Find Delimiters and Headers
                    sniffer = csv.Sniffer()
                    dialect = sniffer.sniff(sample, delimiters=[",", ";", "\t"])
                    has_header = sniffer.has_header(sample)
                    print(f"For {file_name}, the delimiter is '{dialect.delimiter}' and has header: {has_header}")

                    # Reset the file pointer to read again from the start
                    working_file.seek(0)

                    # Load the CSV
                    df = pd.read_csv(
                        working_file,
                        delimiter=dialect.delimiter,
                        header=0 if has_header else None,
                        low_memory=False
                    )

                    # If the file doesn't have headers, assign them now
                    if not has_header:
                        df.columns = header_names
                        print(f"Assigned common headers to {file_name}.")

                    # Parse the datetime column, if it exists
                    if 'datetime' in df.columns:
                        print(f"Parsing 'datetime' column for {file_name}...")
                        df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')

                    print(f"Loaded {file_name} successfully!")

                except Exception as e:
                    print(f"Error loading {file_name}: {e}")
                    continue  # Move to the next file if there's an error

                # Ensure df is not None and has data
                if df is not None and not df.empty:
                    try:
                        # Replace various null representations with a uniform 'NULL'
                        df = df.replace({
                            '/N': 'NULL', 
                            '//N': 'NULL', 
                            ' ': 'NULL', 
                            '': 'NULL', 
                            'NaN': 'NULL', 
                            'nan': 'NULL', 
                            'N': 'NULL',
                            np.nan: 'NULL'
                        })
                        print(f"Missing Values converted to Nulls for {file_name}")

                        # Cast the DataFrame to the schema
                        df = cast_dataframe_to_schema(df, schema)

                        # Save the processed DataFrame
                        processed_filename = os.path.join(
                            processed_files_directory, f"{os.path.splitext(file_name)[0]}_processed.csv"
                        )
                        df.to_csv(processed_filename, index=False)
                        print(f"Processed and saved {file_name}.")

                    except Exception as e:
                        print(f"Error processing {file_name}: {e}")

    print(f"Completed processing ZIP file: {current_zf}")
# Out:
# For transArchive_201001_201003.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201001_201003.csv...
# Loaded transArchive_201001_201003.csv successfully!
# Missing Values converted to Nulls for transArchive_201001_201003.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201001_201003.csv.
# Completed processing ZIP file: transArchive_201001_201003.zip
# For transArchive_201004_201006.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201004_201006.csv...
# Loaded transArchive_201004_201006.csv successfully!
# Missing Values converted to Nulls for transArchive_201004_201006.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201004_201006.csv.
# Completed processing ZIP file: transArchive_201004_201006.zip
# For transArchive_201007_201009.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201007_201009.csv...
# Loaded transArchive_201007_201009.csv successfully!
# Missing Values converted to Nulls for transArchive_201007_201009.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201007_201009.csv.
# Completed processing ZIP file: transArchive_201007_201009.zip
# For transArchive_201010_201012.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201010_201012.csv...
# Loaded transArchive_201010_201012.csv successfully!
# Missing Values converted to Nulls for transArchive_201010_201012.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201010_201012.csv.
# Completed processing ZIP file: transArchive_201010_201012.zip
# For transArchive_201101_201103.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201101_201103.csv...
# Loaded transArchive_201101_201103.csv successfully!
# Missing Values converted to Nulls for transArchive_201101_201103.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201101_201103.csv.
# Completed processing ZIP file: transArchive_201101_201103.zip
# For transArchive_201104.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201104.csv...
# Loaded transArchive_201104.csv successfully!
# Missing Values converted to Nulls for transArchive_201104.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201104.csv.
# Completed processing ZIP file: transArchive_201104.zip
# For transArchive_201105.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201105.csv...
# Loaded transArchive_201105.csv successfully!
# Missing Values converted to Nulls for transArchive_201105.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201105.csv.
# Completed processing ZIP file: transArchive_201105.zip
# For transArchive_201106.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201106.csv...
# Loaded transArchive_201106.csv successfully!
# Missing Values converted to Nulls for transArchive_201106.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201106.csv.
# Completed processing ZIP file: transArchive_201106.zip
# For transArchive_201107_201109.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201107_201109.csv...
# Loaded transArchive_201107_201109.csv successfully!
# Missing Values converted to Nulls for transArchive_201107_201109.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201107_201109.csv.
# Completed processing ZIP file: transArchive_201107_201109.zip
# For transArchive_201110_201112.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201110_201112.csv...
# Loaded transArchive_201110_201112.csv successfully!
# Missing Values converted to Nulls for transArchive_201110_201112.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201110_201112.csv.
# Completed processing ZIP file: transArchive_201110_201112.zip
# For transArchive_201201_201203.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201201_201203.csv...
# Loaded transArchive_201201_201203.csv successfully!
# Missing Values converted to Nulls for transArchive_201201_201203.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201201_201203.csv.
# Completed processing ZIP file: transArchive_201201_201203.zip
# For transArchive_201201_201203_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201201_201203_inactive.csv...
# Loaded transArchive_201201_201203_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201201_201203_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201201_201203_inactive.csv.
# Completed processing ZIP file: transArchive_201201_201203_inactive.zip
# For transArchive_201204_201206.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201204_201206.csv...
# Loaded transArchive_201204_201206.csv successfully!
# Missing Values converted to Nulls for transArchive_201204_201206.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201204_201206.csv.
# Completed processing ZIP file: transArchive_201204_201206.zip
# For transArchive_201204_201206_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201204_201206_inactive.csv...
# Loaded transArchive_201204_201206_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201204_201206_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201204_201206_inactive.csv.
# Completed processing ZIP file: transArchive_201204_201206_inactive.zip
# For transArchive_201207_201209.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201207_201209.csv...
# Loaded transArchive_201207_201209.csv successfully!
# Missing Values converted to Nulls for transArchive_201207_201209.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201207_201209.csv.
# Completed processing ZIP file: transArchive_201207_201209.zip
# For transArchive_201207_201209_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201207_201209_inactive.csv...
# Loaded transArchive_201207_201209_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201207_201209_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201207_201209_inactive.csv.
# Completed processing ZIP file: transArchive_201207_201209_inactive.zip
# For transArchive_201210_201212.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201210_201212.csv...
# Loaded transArchive_201210_201212.csv successfully!
# Missing Values converted to Nulls for transArchive_201210_201212.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201210_201212.csv.
# Completed processing ZIP file: transArchive_201210_201212.zip
# For transArchive_201210_201212_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201210_201212_inactive.csv...
# Loaded transArchive_201210_201212_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201210_201212_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201210_201212_inactive.csv.
# Completed processing ZIP file: transArchive_201210_201212_inactive.zip
# For transArchive_201301_201303.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201301_201303.csv...
# Loaded transArchive_201301_201303.csv successfully!
# Missing Values converted to Nulls for transArchive_201301_201303.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201301_201303.csv.
# Completed processing ZIP file: transArchive_201301_201303.zip
# For transArchive_201301_201303_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201301_201303_inactive.csv...
# Loaded transArchive_201301_201303_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201301_201303_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201301_201303_inactive.csv.
# Completed processing ZIP file: transArchive_201301_201303_inactive.zip
# For transArchive_201304_201306.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201304_201306.csv...
# Loaded transArchive_201304_201306.csv successfully!
# Missing Values converted to Nulls for transArchive_201304_201306.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201304_201306.csv.
# Completed processing ZIP file: transArchive_201304_201306.zip
# For transArchive_201304_201306_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201304_201306_inactive.csv...
# Loaded transArchive_201304_201306_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201304_201306_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201304_201306_inactive.csv.
# Completed processing ZIP file: transArchive_201304_201306_inactive.zip
# For transArchive_201307_201309.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201307_201309.csv...
# Loaded transArchive_201307_201309.csv successfully!
# Missing Values converted to Nulls for transArchive_201307_201309.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201307_201309.csv.
# Completed processing ZIP file: transArchive_201307_201309.zip
# For transArchive_201307_201309_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201307_201309_inactive.csv...
# Loaded transArchive_201307_201309_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201307_201309_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201307_201309_inactive.csv.
# Completed processing ZIP file: transArchive_201307_201309_inactive.zip
# For transArchive_201310_201312.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201310_201312.csv...
# Loaded transArchive_201310_201312.csv successfully!
# Missing Values converted to Nulls for transArchive_201310_201312.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201310_201312.csv.
# Completed processing ZIP file: transArchive_201310_201312.zip
# For transArchive_201310_201312_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201310_201312_inactive.csv...
# Loaded transArchive_201310_201312_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201310_201312_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201310_201312_inactive.csv.
# Completed processing ZIP file: transArchive_201310_201312_inactive.zip
# For transArchive_201401_201403.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201401_201403.csv...
# Loaded transArchive_201401_201403.csv successfully!
# Missing Values converted to Nulls for transArchive_201401_201403.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201401_201403.csv.
# Completed processing ZIP file: transArchive_201401_201403.zip
# For transArchive_201401_201403_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201401_201403_inactive.csv...
# Loaded transArchive_201401_201403_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201401_201403_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201401_201403_inactive.csv.
# Completed processing ZIP file: transArchive_201401_201403_inactive.zip
# For transArchive_201404_201406.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201404_201406.csv...
# Loaded transArchive_201404_201406.csv successfully!
# Missing Values converted to Nulls for transArchive_201404_201406.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201404_201406.csv.
# Completed processing ZIP file: transArchive_201404_201406.zip
# For transArchive_201404_201406_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201404_201406_inactive.csv...
# Loaded transArchive_201404_201406_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201404_201406_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201404_201406_inactive.csv.
# Completed processing ZIP file: transArchive_201404_201406_inactive.zip
# For transArchive_201407_201409.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201407_201409.csv...
# Loaded transArchive_201407_201409.csv successfully!
# Missing Values converted to Nulls for transArchive_201407_201409.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201407_201409.csv.
# Completed processing ZIP file: transArchive_201407_201409.zip
# For transArchive_201407_201409_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201407_201409_inactive.csv...
# Loaded transArchive_201407_201409_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201407_201409_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201407_201409_inactive.csv.
# Completed processing ZIP file: transArchive_201407_201409_inactive.zip
# For transArchive_201410_201412.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201410_201412.csv...
# Loaded transArchive_201410_201412.csv successfully!
# Missing Values converted to Nulls for transArchive_201410_201412.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201410_201412.csv.
# Completed processing ZIP file: transArchive_201410_201412.zip
# For transArchive_201410_201412_inactive.csv, the delimiter is ';' and has header: True
# Parsing 'datetime' column for transArchive_201410_201412_inactive.csv...
# Loaded transArchive_201410_201412_inactive.csv successfully!
# Missing Values converted to Nulls for transArchive_201410_201412_inactive.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201410_201412_inactive.csv.
# Completed processing ZIP file: transArchive_201410_201412_inactive.zip
# For transArchive_201501_201503.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201501_201503.csv...
# Loaded transArchive_201501_201503.csv successfully!
# Missing Values converted to Nulls for transArchive_201501_201503.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201501_201503.csv.
# Completed processing ZIP file: transArchive_201501_201503.zip
# For transArchive_201504_201506.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201504_201506.csv...
# Loaded transArchive_201504_201506.csv successfully!
# Missing Values converted to Nulls for transArchive_201504_201506.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201504_201506.csv.
# Completed processing ZIP file: transArchive_201504_201506.zip
# For transArchive_201507_201509.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201507_201509.csv...
# Loaded transArchive_201507_201509.csv successfully!
# Missing Values converted to Nulls for transArchive_201507_201509.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201507_201509.csv.
# Completed processing ZIP file: transArchive_201507_201509.zip
# For transArchive_201510.csv, the delimiter is ',' and has header: True
# Parsing 'datetime' column for transArchive_201510.csv...
# Loaded transArchive_201510.csv successfully!
# Missing Values converted to Nulls for transArchive_201510.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201510.csv.
# Completed processing ZIP file: transArchive_201510.zip
# For transArchive_201511.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201511.csv.
# Parsing 'datetime' column for transArchive_201511.csv...
# Loaded transArchive_201511.csv successfully!
# Missing Values converted to Nulls for transArchive_201511.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201511.csv.
# Completed processing ZIP file: transArchive_201511.zip
# For transArchive_201512.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201512.csv.
# Parsing 'datetime' column for transArchive_201512.csv...
# Loaded transArchive_201512.csv successfully!
# Missing Values converted to Nulls for transArchive_201512.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201512.csv.
# Completed processing ZIP file: transArchive_201512.zip
# For transArchive_201601.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201601.csv.
# Parsing 'datetime' column for transArchive_201601.csv...
# Loaded transArchive_201601.csv successfully!
# Missing Values converted to Nulls for transArchive_201601.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201601.csv.
# Completed processing ZIP file: transArchive_201601.zip
# For transArchive_201602.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201602.csv.
# Parsing 'datetime' column for transArchive_201602.csv...
# Loaded transArchive_201602.csv successfully!
# Missing Values converted to Nulls for transArchive_201602.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201602.csv.
# Completed processing ZIP file: transArchive_201602.zip
# For transArchive_201603.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201603.csv.
# Parsing 'datetime' column for transArchive_201603.csv...
# Loaded transArchive_201603.csv successfully!
# Missing Values converted to Nulls for transArchive_201603.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201603.csv.
# Completed processing ZIP file: transArchive_201603.zip
# For transArchive_201604.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201604.csv.
# Parsing 'datetime' column for transArchive_201604.csv...
# Loaded transArchive_201604.csv successfully!
# Missing Values converted to Nulls for transArchive_201604.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201604.csv.
# Completed processing ZIP file: transArchive_201604.zip
# For transArchive_201605.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201605.csv.
# Parsing 'datetime' column for transArchive_201605.csv...
# Loaded transArchive_201605.csv successfully!
# Missing Values converted to Nulls for transArchive_201605.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201605.csv.
# Completed processing ZIP file: transArchive_201605.zip
# For transArchive_201606.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201606.csv.
# Parsing 'datetime' column for transArchive_201606.csv...
# Loaded transArchive_201606.csv successfully!
# Missing Values converted to Nulls for transArchive_201606.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201606.csv.
# Completed processing ZIP file: transArchive_201606.zip
# For transArchive_201607.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201607.csv.
# Parsing 'datetime' column for transArchive_201607.csv...
# Loaded transArchive_201607.csv successfully!
# Missing Values converted to Nulls for transArchive_201607.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201607.csv.
# Completed processing ZIP file: transArchive_201607.zip
# For transArchive_201608.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201608.csv.
# Parsing 'datetime' column for transArchive_201608.csv...
# Loaded transArchive_201608.csv successfully!
# Missing Values converted to Nulls for transArchive_201608.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201608.csv.
# Completed processing ZIP file: transArchive_201608.zip
# For transArchive_201609.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201609.csv.
# Parsing 'datetime' column for transArchive_201609.csv...
# Loaded transArchive_201609.csv successfully!
# Missing Values converted to Nulls for transArchive_201609.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201609.csv.
# Completed processing ZIP file: transArchive_201609.zip
# For transArchive_201610.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201610.csv.
# Parsing 'datetime' column for transArchive_201610.csv...
# Loaded transArchive_201610.csv successfully!
# Missing Values converted to Nulls for transArchive_201610.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201610.csv.
# Completed processing ZIP file: transArchive_201610.zip
# For transArchive_201611.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201611.csv.
# Parsing 'datetime' column for transArchive_201611.csv...
# Loaded transArchive_201611.csv successfully!
# Missing Values converted to Nulls for transArchive_201611.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201611.csv.
# Completed processing ZIP file: transArchive_201611.zip
# For transArchive_201612.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201612.csv.
# Parsing 'datetime' column for transArchive_201612.csv...
# Loaded transArchive_201612.csv successfully!
# Missing Values converted to Nulls for transArchive_201612.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201612.csv.
# Completed processing ZIP file: transArchive_201612.zip
# For transArchive_201701.csv, the delimiter is ',' and has header: False
# Assigned common headers to transArchive_201701.csv.
# Parsing 'datetime' column for transArchive_201701.csv...
# Loaded transArchive_201701.csv successfully!
# Missing Values converted to Nulls for transArchive_201701.csv
# Casting DataFrame to BigQuery schema
# Processed and saved transArchive_201701.csv.
# Completed processing ZIP file: transArchive_201701.zip
